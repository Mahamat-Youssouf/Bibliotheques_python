# %% [markdown]
# # Corrélations de variables

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
correlation = iris.corr()

# %%
correlation
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(correlation, annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(correlation, annot = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(correlation, annot = True, cmap = 'seismic')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(correlation, annot = True, cmap = 'seismic', linewidths = 4, linecolor = 'y')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Représentation d’un tableau croisé dynamique

# %%
airPassagers = pd.read_csv('vols.csv')

# %%
airPassagers.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
airPassagers['year'].unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960], dtype=int64)

# %%
ap = airPassagers.pivot_table(index = 'month', columns = 'year', values = 'passengers')

# %%
ap
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# April       129   135   163   181   235   227   269   313   348   348   396
# August      148   170   199   242   272   293   347   405   467   505   559
# December    118   140   166   194   201   229   278   306   336   337   405
# February    118   126   150   180   196   188   233   277   301   318   342
# January     112   115   145   171   196   204   242   284   315   340   360
# July        148   170   199   230   264   302   364   413   465   491   548
# June        135   149   178   218   243   264   315   374   422   435   472
# March       132   141   178   193   236   235   267   317   356   362   406
# May         121   125   172   183   229   234   270   318   355   363   420
# November    104   114   146   172   180   203   237   271   305   310   362
# October     119   133   162   191   211   229   274   306   347   359   407
# ...

# %%
sns.heatmap(ap)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(ap, linewidths = 2, linecolor = 'y', cmap = 'seismic')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.lmplot(x = 'sepal.length', y = 'petal.length', data = iris)

# %%
sns.lmplot(x = 'sepal.length', y = 'petal.length', data = iris, hue = 'variety')

# %%
sns.lmplot(x = 'sepal.length', y = 'petal.length', data = iris, hue = 'variety', markers = ['o', 'p','v'])

# %%
sns.lmplot(x = 'sepal.length', y = 'petal.length', data = iris, hue = 'variety', markers = ['o', 'p','v'],
          scatter_kws = {'s': 70})

# %%
sns.lmplot(x = 'sepal.length', y = 'petal.length', data = iris, col = 'variety')
